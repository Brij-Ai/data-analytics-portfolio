# %% [markdown]
# <a href="https://colab.research.google.com/github/Brij-Ai/data-analytics-portfolio/blob/main/xMatPlot_Work_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Student_Performance_2026.csv')

# %%
age = np.array(df['Age']) # storing ages of the students

# %%
age
# Out:
# array([23, 24, 18, 17, 23, 25, 25, 24, 18, 18, 23, 21, 17, 19, 23, 17, 22,
#        17, 19, 21, 19, 22, 23, 20, 21, 24, 18, 18, 19, 20, 21, 25, 19, 25,
#        25, 25, 21, 20, 24, 19, 19, 20, 19, 22, 21, 17, 25, 17, 18, 18, 18,
#        23, 23, 23, 19, 22, 17, 22, 20, 24, 21, 17, 21, 23, 21, 21, 22, 17,
#        18, 19, 17, 19, 18, 20, 24, 23, 23, 20, 25, 19, 20, 21, 23, 17, 18,
#        24, 25, 23, 20, 25, 22, 22, 25, 21, 24, 24, 22, 22, 24, 22, 25, 19,
#        21, 21, 19, 24, 17, 23, 22, 18, 19, 17, 19, 24, 18, 22, 17, 22, 20,
#        22, 24, 22, 23, 17, 20, 25, 22, 23, 23, 24, 22, 24, 20, 22, 17, 24,
#        24, 21, 24, 21, 20, 24, 25, 24, 24, 23, 23, 17, 20, 18, 20, 24, 20,
#        25, 17, 25, 25, 19, 18, 22, 17, 17, 24, 24, 19, 17, 23, 17, 17, 22,
#        18, 20, 23, 20, 18, 25, 17, 18, 23, 18, 20, 23, 24, 21, 17, 20, 24,
#        19, 25, 25, 18, 21, 23, 21, 18, 23, 23, 20, 19, 23, 25, 23, 19, 25,
# ...

# %%
sleep_hours = np.array(df['sleep_hours']) # storing cgpa of the students

# %%
df.columns
# Out:
# Index(['student_ID', 'Age', 'Gender', 'daily_screen_time_hours',
#        'social_media_hours', 'online_study_hours', 'gaming_hours',
#        'sleep_hours', 'attendance_percentage', 'offline_study_hours',
#        'previous_sem_CGPA', 'current_sem_CGPA'],
#       dtype='object')

# %%
df.plot(x = 'Age', y = 'gaming_hours', kind = 'bar')
plt.show()

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
col = np.array(df.columns)
print(col)
# Out:
# ['student_ID' 'Age' 'Gender' 'daily_screen_time_hours'
#  'social_media_hours' 'online_study_hours' 'gaming_hours' 'sleep_hours'
#  'attendance_percentage' 'offline_study_hours' 'previous_sem_CGPA'
#  'current_sem_CGPA']

# %%
df.plot(x = 'sleep_hours', y = 'gaming_hours', kind = 'bar')
plt.show()

# %%
col
# Out:
# array(['student_ID', 'Age', 'Gender', 'daily_screen_time_hours',
#        'social_media_hours', 'online_study_hours', 'gaming_hours',
#        'sleep_hours', 'attendance_percentage', 'offline_study_hours',
#        'previous_sem_CGPA', 'current_sem_CGPA'], dtype=object)

# %%
df.plot(x = 'social_media_hours', y = 'online_study_hours', kind = 'area')
plt.show()

# %%
df.plot(x = 'sleep_hours', y = 'gaming_hours', kind = 'line')
plt.show()

# %%
newDf = df[0:20]

# %%
newDf
# Out:
#    student_ID  Age  Gender  daily_screen_time_hours  social_media_hours  \
# 0        S011   23  Female                      6.2                 2.5
# 1        S012   24  Female                      4.9                 2.0
# 2        S013   18  Female                      7.9                 3.2
# 3        S014   17    Male                     10.0                 4.0
# 4        S015   23  Female                      7.7                 3.1
# 5        S016   25    Male                      7.6                 3.0
# 6        S017   25  Female                      4.1                 1.6
# 7        S018   24    Male                      4.6                 1.8
# 8        S019   18  Female                      5.0                 2.0
# 9        S020   18  Female                      7.1                 2.8
# 10       S021   23  Female                      9.4                 3.8
# 11       S022   21  Female                      4.3                 1.7
# ...

# %%
newDf.plot(x = 'Age', y = 'social_media_hours', kind = 'barh')
plt.show()

# %%
newDf['Gender']
# Out:
# 0     Female
# 1     Female
# 2     Female
# 3       Male
# 4     Female
# 5       Male
# 6     Female
# 7       Male
# 8     Female
# 9     Female
# 10    Female
# 11    Female
# 12      Male
# 13      Male
# 14    Female
# 15    Female
# 16      Male
# 17      Male
# 18      Male
# 19      Male
# Name: Gender, dtype: object

# %%
newDf.plot()
# Out:
# <Axes: >

# %%
df.plot()
# Out:
# <Axes: >

# %%
# new data (ramen ratings)

# %%
ramen_RT = pd.read_csv('/content/ramen-ratings.csv')

# %%
ramen_RT
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %%
country = np.array(ramen_RT['Country'])

# %%
ramen_RT.plot(kind = 'bar')
plt.show()

# %%
country
# Out:
# array(['Japan', 'Taiwan', 'USA', ..., 'Thailand', 'Thailand', 'USA'],
#       dtype=object)

# %%
DF = pd.read_csv('/content/ramen-ratings.csv')
DF
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %%
DF.Country.value_counts().plot(kind = 'bar')
plt.show()

# %%
DF.Style.value_counts().plot(kind = 'barh')
plt.show()

# %%
DF
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...
